# %%
# loads data set
import pandas as pd
df = pd.read_excel("C:\\Users\\\harry\\\Desktop\\\github\\resources\\ATTRITION DATA.xlsx")

# %%
# converting number variables into categories
cols = ['status','job_level','no_of_promotions','risk_of_attrition','potential_rating']

for col in cols:
    df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   e_code                   686 non-null    int64
#  1   status                   686 non-null    category
#  2   hire_date                686 non-null    datetime64[ns]
#  3   service_agreement        686 non-null    object
#  4   job_level                686 non-null    category
#  5   performance_rating_2018  686 non-null    int64
#  6   performance_rating_2017  686 non-null    int64
#  7   year_of_birth            686 non-null    int64
#  8   gender                   686 non-null    object
#  9   distance_from_home       686 non-null    float64
#  10  manager_changes          686 non-null    int64
#  11  no_of_promotions         686 non-null    category
#  12  risk_of_attrition        686 non-null    category
# ...

# %%
# calculating age of employee by subtracting year of birth from 2018
df['age']=2018-df['year_of_birth']

# %%
import pingouin as pg
pg.ttest(df['age'], df['status'], correction=True)
# Out:
# C:\Users\harry\anaconda3\lib\site-packages\pingouin\bayesian.py:146: RuntimeWarning: divide by zero encountered in double_scalars
#   bf10 = 1 / ((1 + t**2 / df)**(-(df + 1) / 2) / integr)
#                  T         dof alternative  p-val          CI95%   cohen-d  \
# T-test  152.895062  689.275165   two-sided    0.0  [44.64, 45.8]  8.255557
#
#        BF10  power
# T-test  inf    1.0

# %%
import scipy.stats as sp
sp.stats.ttest_ind(df['age'], df['status'], equal_var=False)
# Out:
# Ttest_indResult(statistic=152.89506180745045, pvalue=0.0)

# %%
df.head()
# Out:
#    e_code status  hire_date service_agreement job_level  \
# 0   45631      0 1990-09-17                 N         3
# 1   45632      0 1995-10-23                 N         2
# 2   45633      0 1996-03-10                 N         2
# 3   45634      0 1998-07-13                 N         1
# 4   45635      0 1991-09-16                 N         2
#
#    performance_rating_2018  performance_rating_2017  year_of_birth gender  \
# 0                        4                        3           1967      M
# 1                        1                        2           1971      M
# 2                        4                        4           1972      M
# 3                        3                        3           1968      F
# 4                        3                        3           1961      M
#
#    distance_from_home  ...  bonus no_courses_taken time_in_position awards  \
# 0                0.52  ...      0                8               30      N
# ...

# %%
df.to_dict('series')
# Out:
# {'e_code': 0      45631
#  1      45632
#  2      45633
#  3      45634
#  4      45635
#         ...
#  681    46267
#  682    46290
#  683    46312
#  684    46336
#  685    46359
#  Name: e_code, Length: 686, dtype: int64,
#  'status': 0      0
#  1      0
#  2      0
#  3      0
#  4      0
#        ..
#  681    1
#  682    1
#  683    1
#  684    1
#  685    1
#  Name: status, Length: 686, dtype: category
#  Categories (2, int64): [0, 1],
#  'hire_date': 0     1990-09-17
#  1     1995-10-23
#  2     1996-03-10
#  3     1998-07-13
#  4     1991-09-16
#           ...
#  681   2008-07-07
#  682   2011-07-25
#  683   2012-11-26
#  684   2002-07-04
#  685   2015-03-02
#  Name: hire_date, Length: 686, dtype: datetime64[ns],
#  'service_agreement': 0      N
#  1      N
#  2      N
#  3      N
#  4      N
#        ..
#  681    N
#  682    N
#  683    N
#  684    N
#  685    Y
#  Name: service_agreement, Length: 686, dtype: object,
#  'job_level': 0      3
#  1      2
#  2      2
# ...

# %%
sp.stats.ttest_ind(df.query('status==0')['age'], df.query('status==1')['age'], equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.30302035013621026, pvalue=0.7620774744278347)
