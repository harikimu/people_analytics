# %% [markdown]
# # Importing Excel File in Python

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\heeckim\\Desktop\\work\\12_python\\pyharry\\resources\\LR DATA.xlsx') # 판다스로 데이터프레임으로 엑셀파일 불러오기

# %%
df.shape # Row, Column수 반환
# Out:
# (1470, 17)

# %%
df.columns # Column 이름 반환
# Out:
# Index(['age', 'department', 'employee_number', 'gender', 'job_level',
#        'marital_status', 'over_time', 'performance_rating',
#        'totalW_working_years', 'training_times_last_year',
#        'years_since_last_promotion', 'years_with_curr_manager',
#        'monthly_income', 'salary_2017', 'salary_2018', 'year_of_joining',
#        'last_role_change'],
#       dtype='object')

# %%
df.head() # 첫 5 Index 반환 test
# Out:
#    age              department  employee_number  gender  job_level  \
# 0   41                   Sales                1  Female          2
# 1   49  Research & Development                2    Male          2
# 2   37  Research & Development                4    Male          1
# 3   33  Research & Development                5  Female          1
# 4   27  Research & Development                7    Male          1
#
#   marital_status over_time  performance_rating  totalW_working_years  \
# 0         Single       Yes                   3                     8
# 1        Married        No                   4                    10
# 2         Single       Yes                   3                     7
# 3        Married       Yes                   3                     8
# 4        Married        No                   3                     6
#
#    training_times_last_year  years_since_last_promotion  \
# 0                         0                           0
# ...

# %%
df.tail() # 마지막 5 Index 반환
# Out:
#       age              department  employee_number gender  job_level  \
# 1465   36  Research & Development             2061   Male          2
# 1466   39  Research & Development             2062   Male          3
# 1467   27  Research & Development             2064   Male          2
# 1468   49                   Sales             2065   Male          2
# 1469   34  Research & Development             2068   Male          2
#
#      marital_status over_time  performance_rating  totalW_working_years  \
# 1465        Married        No                   3                    17
# 1466        Married        No                   3                     9
# 1467        Married       Yes                   4                     6
# 1468        Married        No                   3                    17
# 1469        Married        No                   3                     6
#
#       training_times_last_year  years_since_last_promotion  \
# ...

# %%
df.dtypes # 각 컬럼별 데이터 타입 반환
# Out:
# age                             int64
# department                     object
# employee_number                 int64
# gender                         object
# job_level                       int64
# marital_status                 object
# over_time                      object
# performance_rating              int64
# totalW_working_years            int64
# training_times_last_year        int64
# years_since_last_promotion      int64
# years_with_curr_manager         int64
# monthly_income                  int64
# salary_2017                     int64
# salary_2018                   float64
# year_of_joining                 int64
# last_role_change                int64
# dtype: object

# %%
dasd
